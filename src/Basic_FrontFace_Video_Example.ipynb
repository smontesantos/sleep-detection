# %%
import Basic_Library as blib
import dlib
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Image processing libraries
import cv2 
import dlib

# Local library
import Basic_Library as blib

# %%
# Import face detector.
detector = dlib.get_frontal_face_detector()

# Import landmark predictor.
landmark_predictor_path = os.path.join('..', 'models', 'shape_predictor_68_face_landmarks.dat' )
predictor = dlib.shape_predictor(landmark_predictor_path)

# %%
# Try different camera indices (0, 1, 2, etc.)
for camera_index in range(100):
    cap = cv2.VideoCapture(camera_index)
    if cap.isOpened():
        print(f"Camera opened successfully with index {camera_index}")
        break
    else:
        print(f"Error: Could not open camera with index {camera_index}")
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Check if the frame was captured successfully
    if not ret:
        print("Error: Could not read frame.")
        break
    
    # Display the frame
    cv2.imshow("Camera Feed", frame)

    # Break the loop if 'q' is pressed
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open camera with index 0
# Error: Could not open camera with index 1
# Error: Could not open camera with index 2
# Error: Could not open camera with index 3
# Error: Could not open camera with index 4
# Error: Could not open camera with index 5
# Error: Could not open camera with index 6
# Error: Could not open camera with index 7
# Error: Could not open camera with index 8
# Error: Could not open camera with index 9
# Error: Could not open camera with index 10
# Error: Could not open camera with index 11
# Error: Could not open camera with index 12
# Error: Could not open camera with index 13
# Error: Could not open camera with index 14
# Error: Could not open camera with index 15
# Error: Could not open camera with index 16
# Error: Could not open camera with index 17
# Error: Could not open camera with index 18
# Error: Could not open camera with index 19
# Error: Could not open camera with index 20
# Error: Could not open camera with index 21
# Error: Could not open camera with index 22
# Error: Could not open camera with index 23
# Error: Could not open camera with index 24
# Error: Could not open camera with index 25
# Error: Could not open camera with index 26
# Error: Could not open camera with index 27
# Error: Could not open camera with index 28
# Error: Could not open camera with index 29
# Error: Could not open camera with index 30
# Error: Could not open camera with index 31
# Error: Could not open camera with index 32
# Error: Could not open camera with index 33
# Error: Could not open camera with index 34
# Error: Could not open camera with index 35
# Error: Could not open camera with index 36
# Error: Could not open camera with index 37
# Error: Could not open camera with index 38
# Error: Could not open camera with index 39
# Error: Could not open camera with index 40
# Error: Could not open camera with index 41
# Error: Could not open camera with index 42
# Error: Could not open camera with index 43
# Error: Could not open camera with index 44
# Error: Could not open camera with index 45
# Error: Could not open camera with index 46
# Error: Could not open camera with index 47
# Error: Could not open camera with index 48
# Error: Could not open camera with index 49
# Error: Could not open camera with index 50
# Error: Could not open camera with index 51
# Error: Could not open camera with index 52
# Error: Could not open camera with index 53
# Error: Could not open camera with index 54
# Error: Could not open camera with index 55
# Error: Could not open camera with index 56
# Error: Could not open camera with index 57
# Error: Could not open camera with index 58
# Error: Could not open camera with index 59
# Error: Could not open camera with index 60
# Error: Could not open camera with index 61
# Error: Could not open camera with index 62
# Error: Could not open camera with index 63
# Error: Could not open camera with index 64
# Error: Could not open camera with index 65
# Error: Could not open camera with index 66
# Error: Could not open camera with index 67
# Error: Could not open camera with index 68
# Error: Could not open camera with index 69
# Error: Could not open camera with index 70
# Error: Could not open camera with index 71
# Error: Could not open camera with index 72
# Error: Could not open camera with index 73
# Error: Could not open camera with index 74
# Error: Could not open camera with index 75
# Error: Could not open camera with index 76
# Error: Could not open camera with index 77
# Error: Could not open camera with index 78
# Error: Could not open camera with index 79
# Error: Could not open camera with index 80
# Error: Could not open camera with index 81
# Error: Could not open camera with index 82
# Error: Could not open camera with index 83
# Error: Could not open camera with index 84
# Error: Could not open camera with index 85
# Error: Could not open camera with index 86
# Error: Could not open camera with index 87
# Error: Could not open camera with index 88
# Error: Could not open camera with index 89
# Error: Could not open camera with index 90
# Error: Could not open camera with index 91
# Error: Could not open camera with index 92
# Error: Could not open camera with index 93
# Error: Could not open camera with index 94
# Error: Could not open camera with index 95
# Error: Could not open camera with index 96
# Error: Could not open camera with index 97
# Error: Could not open camera with index 98
# Error: Could not open camera with index 99
# Error: Could not open camera.
# Error: Could not read frame.
# [ WARN:0@0.887] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@0.887] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.888] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ERROR:0@0.888] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video3): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video4): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video5): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video6): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video7): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video8): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video9): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video10): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video11): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.889] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video12): can't open camera by index
# [ERROR:0@0.889] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video13): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video14): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video15): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video16): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video17): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video18): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video19): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video20): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video21): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video22): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video23): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video24): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video25): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video26): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video27): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video28): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video29): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video30): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video31): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video32): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video33): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video34): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video35): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video36): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video37): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video38): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video39): can't open camera by index
# [ERROR:0@0.890] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.890] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video40): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video41): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video42): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video43): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video44): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video45): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video46): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video47): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video48): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video49): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video50): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video51): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video52): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video53): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video54): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video55): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video56): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video57): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video58): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video59): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.891] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video60): can't open camera by index
# [ERROR:0@0.891] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video61): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video62): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video63): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video64): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video65): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video66): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video67): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video68): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video69): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video70): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video71): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video72): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video73): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video74): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video75): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video76): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video77): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video78): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video79): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video80): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video81): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video82): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video83): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video84): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video85): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video86): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video87): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video88): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video89): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.892] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video90): can't open camera by index
# [ERROR:0@0.892] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video91): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video92): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video93): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video94): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video95): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video96): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video97): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video98): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# [ WARN:0@0.893] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video99): can't open camera by index
# [ERROR:0@0.893] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range

# %%
# cap = cv2.VideoCapture(0)
# 
# if not cap.isOpened():
#     print("Error: Could not open camera.")
#     exit()
#  
# while True:
#     # load the input image and convert it to grayscale
#     _, image = cap.read()
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#         
#     # detect faces in the grayscale image
#     faces = detector(gray, 0)
#     
#     # loop over the face detections
#     for (i, face) in enumerate(faces):
# 
#         # Display the bbox for the detected face.
#         cv2.rectangle(image, (face.left(), face.top()), (face.right(), face.bottom()), (255, 0, 0), 12)
# 
# 
#         # determine the facial landmarks for the face region, then
#         # convert the facial landmark (x, y)-coordinates to a NumPy
#         # array
#         shape = predictor(gray, face)
#         shape = blib.shape_to_np(shape)
#     
#         # loop over the (x, y)-coordinates for the facial landmarks
#         # and draw them on the image
#         for (x, y) in shape:
#             cv2.circle(image, (x, y), 2, (255, 0, 0), -1)
#     
#     # show the output image with the face detections + facial landmarks
#     cv2.imshow("Output", image)
#     k = cv2.waitKey(5) & 0xFF
#     if k == 27:
#         break

cv2.destroyAllWindows()
cap.release()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
